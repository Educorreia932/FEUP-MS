# %%
import pandas as pd
import math

df = pd.read_csv('2023_12_16.txt')
df
# Out:
#         who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 0     50202     0      43.107643       4.488705                  1
# 1     50202     0      43.043111       4.195727                  1
# 2     50202     1      42.967134       4.485947                  1
# 3     50202     2      42.891156       4.776167                  1
# 4     50202     3      42.815178       5.066386                  1
# ...     ...   ...            ...            ...                ...
# 2944  49899   155      50.894720       5.316595                  1
# 2945  49899   156      51.087610       5.086827                  1
# 2946  49899   157      51.280500       4.857059                  1
# 2947  49899   158      51.473390       4.627291                  1
# 2948  49899   159      51.666280       4.397522                  1
#
#       platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 0                     1                11                 3             none
# 1                     1                11                 3             none
# 2                     1                11                 3             none
# 3                     1                11                 4             none
# 4                     1                11                 4             none
# ...                 ...               ...               ...              ...
# 2944                  1                19                 4             none
# 2945                  1                19                 4             none
# 2946                  1                19                 4             none
# 2947                  1                19                 4             none
# 2948                  1                20                 3             none
#
#       xcor-final-pos  ycor-final-pos  floor-id-final-pos  platform--final-pos  \
# 0          43.107643        4.488705                   1                    1
# 1          43.043111        4.195727                   1                    1
# 2          42.967134        4.485947                   1                    1
# 3          42.891156        4.776167                   1                    1
# 4          42.815178        5.066386                   1                    1
# ...              ...             ...                 ...                  ...
# 2944       50.894720        5.316595                   1                    1
# 2945       51.087610        5.086827                   1                    1
# 2946       51.280500        4.857059                   1                    1
# 2947       51.473390        4.627291                   1                    1
# 2948       51.666280        4.397522                   1                    1
#
#       floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 0                    11                  3  171.000000              0
# 1                    11                  3  192.421713              0
# 2                    11                  3  345.329549              0
# 3                    11                  4  345.329549              0
# 4                    11                  4  345.329549              0
# ...                 ...                ...         ...            ...
# 2944                 19                  4  139.986571              0
# 2945                 19                  4  139.986571              0
# 2946                 19                  4  139.986571              0
# 2947                 19                  4  139.986571              0
# 2948                 20                  3  139.986571              0
#
#       crowdness-1  crowdness-1.2  crowdness-1.4
# 0               0              0              0
# 1               0              0              0
# 2               0              0              0
# 3               0              0              0
# 4               0              0              0
# ...           ...            ...            ...
# 2944            0              0              0
# 2945            0              0              0
# 2946            0              0              0
# 2947            0              0              0
# 2948            0              0              0
#
# [2949 rows x 20 columns]

# %%
df.describe()
# Out:
#        xcor-init-pos  ycor-init-pos  floor-id-init-pos  platform-init-pos  \
# count    2949.000000    2949.000000        2949.000000        2949.000000
# mean       25.616672      15.132842           0.392336           0.392336
# std        16.135662       5.626134           0.488354           0.488354
# min         4.901498       2.248640           0.000000           0.000000
# 25%        11.570226      10.740674           0.000000           0.000000
# 50%        17.350342      15.941190           0.000000           0.000000
# 75%        42.958186      19.654529           1.000000           1.000000
# max        53.616867      23.047940           1.000000           1.000000
#
#        floor-x-init-pos  floor-y-init-pos  xcor-final-pos  ycor-final-pos  \
# count       2949.000000       2949.000000     2949.000000     2949.000000
# mean          12.458121         14.155985       25.616672       15.132842
# std            4.002292          5.662975       16.136120        5.626134
# min            4.000000          1.000000        4.901498        2.248640
# 25%            9.000000         10.000000       11.570226       10.740674
# 50%           12.000000         15.000000       17.350342       15.941190
# 75%           16.000000         19.000000       42.958186       19.654529
# max           22.000000         22.000000       53.616867       23.047940
#
#        floor-id-final-pos  platform--final-pos  floor-x-final-pos  \
# count         2949.000000          2949.000000        2949.000000
# mean             0.392336             0.392336          12.458121
# std              0.488354             0.488354           4.002292
# min              0.000000             0.000000           4.000000
# 25%              0.000000             0.000000           9.000000
# 50%              0.000000             0.000000          12.000000
# 75%              1.000000             1.000000          16.000000
# max              1.000000             1.000000          22.000000
#
#        floor-y-final-pos      heading  crowdness-0.8  crowdness-1  \
# count        2949.000000  2949.000000    2949.000000  2949.000000
# mean           14.155985   182.364573       0.010173     0.480841
# std             5.662975   104.432080       0.118926     0.723741
# min             1.000000     0.078995       0.000000     0.000000
# 25%            10.000000    87.516669       0.000000     0.000000
# 50%            15.000000   180.819139       0.000000     0.000000
# 75%            19.000000   268.436649       0.000000     1.000000
# max            22.000000   359.912159       2.000000     4.000000
#
#        crowdness-1.2  crowdness-1.4
# count    2949.000000    2949.000000
# mean        0.665988       0.888437
# std         0.852007       0.907584
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       1.000000
# 75%         1.000000       1.000000
# max         5.000000       5.000000

# %% [markdown]
# Distancia Percorrida

# %%
def distance_calc(x_init_pos, y_init_pos, x_final_pos, y_final_pos):
    distance = math.sqrt(((x_init_pos-x_final_pos)**2)+((y_init_pos-y_final_pos)**2))
    return distance

turtle = df.at[0,"who"]
for i in range(len(df)):
    while(df.loc[i,'who']==turtle):
        if(df.loc[i,'tick']==0):
            x_init_pos = df.loc[i,'xcor-init-pos']
            y_init_pos = df.loc[i,'ycor-init-pos']
# Out:
# 50202
