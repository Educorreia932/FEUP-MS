# %%
import pandas as pd
import math
import numpy as np

df = pd.read_csv('2023_12_29_00_40_12_tickdata.txt')
df
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#       who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 0     405     0       5.778839      15.597595                  0
# 1     405     1       5.923333      15.860504                  0
# 2     405     2       6.132281      16.075774                  0
# 3     405     3       6.341229      16.291043                  0
# 4     405     4       6.550176      16.506312                  0
# ...   ...   ...            ...            ...                ...
# 2269  300    69      22.575756       4.833511                  0
# 2270  300    70      22.834676       4.681983                  0
# 2271  300    71      23.093595       4.530455                  0
# 2272  300    72      23.352515       4.378928                  0
# 2273  300    73      23.611435       4.227400                  0
#
#       platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 0                     0                 5                15             none
# 1                     0                 5                15             none
# 2                     0                 5                15             none
# 3                     0                 5                15             none
# 4                     0                 6                16             none
# ...                 ...               ...               ...              ...
# 2269                  0                22                 4             none
# 2270                  0                22                 4             none
# 2271                  0                22                 4             none
# 2272                  0                22                 3             none
# 2273                  0                23                 3             none
#
#       xcor-final-pos  ycor-final-pos  floor-id-final-pos  platform--final-pos  \
# 0           5.778839       15.597595                   0                    0
# 1           5.923333       15.860504                   0                    0
# 2           6.132281       16.075774                   0                    0
# 3           6.341229       16.291043                   0                    0
# 4           6.550176       16.506312                   0                    0
# ...              ...             ...                 ...                  ...
# 2269       22.575756        4.833511                   0                    0
# 2270       22.834676        4.681983                   0                    0
# 2271       23.093595        4.530455                   0                    0
# 2272       23.352515        4.378928                   0                    0
# 2273       23.611435        4.227400                   0                    0
#
#       floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 0                     5                 15   19.000000              0
# 1                     5                 15   28.793167              0
# 2                     5                 15   44.146246              0
# 3                     5                 15   44.146246              0
# 4                     6                 16   44.146246              0
# ...                 ...                ...         ...            ...
# 2269                 22                  4  120.337458              0
# 2270                 22                  4  120.337458              0
# 2271                 22                  4  120.337458              0
# 2272                 22                  3  120.337458              0
# 2273                 23                  3  120.337458              0
#
#       crowdness-1  crowdness-1.2  crowdness-1.4
# 0               0              0              0
# 1               0              0              0
# 2               0              0              0
# 3               0              0              0
# 4               0              0              0
# ...           ...            ...            ...
# 2269            0              0              0
# 2270            0              0              0
# 2271            0              0              0
# 2272            0              0              0
# 2273            0              0              0
#
# [2274 rows x 20 columns]

# %%
df.describe()
# Out:
#                who         tick  xcor-init-pos  ycor-init-pos  \
# count  2274.000000  2274.000000    2274.000000    2274.000000
# mean    353.207124    61.313105      26.886116      15.764108
# std      41.351250    39.837787      15.847360       6.367307
# min     289.000000     0.000000       5.023428       2.047565
# 25%     324.000000    28.000000      12.748393      10.366008
# 50%     339.000000    57.000000      20.515067      17.275162
# 75%     394.000000    92.000000      44.585339      20.725105
# max     428.000000   173.000000      53.669601      29.115250
#
#        floor-id-init-pos  platform-init-pos  floor-x-init-pos  \
# count        2274.000000        2274.000000       2274.000000
# mean            0.396658           0.396658         13.600264
# std             0.489311           0.489311          4.414193
# min             0.000000           0.000000          4.000000
# 25%             0.000000           0.000000         10.000000
# 50%             0.000000           0.000000         13.000000
# 75%             1.000000           1.000000         17.000000
# max             1.000000           1.000000         23.000000
#
#        floor-y-init-pos  xcor-final-pos  ycor-final-pos  floor-id-final-pos  \
# count       2274.000000     2274.000000     2274.000000         2274.000000
# mean          14.784081       26.817954       15.764108            0.394459
# std            6.398794       15.850980        6.367307            0.488842
# min            1.000000        5.023428        2.047565            0.000000
# 25%            9.000000       12.681656       10.366008            0.000000
# 50%           16.000000       20.483714       17.275162            0.000000
# 75%           20.000000       44.585339       20.725105            1.000000
# max           28.000000       53.669601       29.115250            1.000000
#
#        platform--final-pos  floor-x-final-pos  floor-y-final-pos      heading  \
# count          2274.000000        2274.000000        2274.000000  2274.000000
# mean              0.394459          13.600264          14.784081   167.785573
# std               0.488842           4.414193           6.398794   107.710296
# min               0.000000           4.000000           1.000000     0.000000
# 25%               0.000000          10.000000           9.000000    87.512321
# 50%               0.000000          13.000000          16.000000   164.997550
# 75%               1.000000          17.000000          20.000000   266.825164
# max               1.000000          23.000000          28.000000   359.777827
#
#        crowdness-0.8  crowdness-1  crowdness-1.2  crowdness-1.4
# count    2274.000000  2274.000000    2274.000000    2274.000000
# mean        0.003518     0.117854       0.214600       0.246262
# std         0.059222     0.338480       0.453405       0.491052
# min         0.000000     0.000000       0.000000       0.000000
# 25%         0.000000     0.000000       0.000000       0.000000
# 50%         0.000000     0.000000       0.000000       0.000000
# 75%         0.000000     0.000000       0.000000       0.000000
# max         1.000000     2.000000       3.000000       3.000000

# %% [markdown]
# Split table by turtle

# %%
#list with unique turtle id
uniqueTurtle = df.who.unique()
uniqueTurtle
# Out:
# array([405, 383, 324, 416, 301, 372, 323, 289, 361, 339, 312, 394, 326,
#        350, 325, 338, 337, 417, 428, 300])

# %% [markdown]
# Calcular Distancia Percorrida

# %%
def distance_calc(x_init_pos, y_init_pos, x_final_pos, y_final_pos):
    distance = math.sqrt(((x_init_pos-x_final_pos)**2)+((y_init_pos-y_final_pos)**2))
    return distance

# for i in range(len(uniqueTurtle)):
#     current_table=df[df['who']==uniqueTurtle[i]]
#     print(current_table.head())
#     current_table.loc[0,2]

df['distance'] = np.nan
turtles_df = df.groupby('who')

# %%
one_turtle = list(turtles_df.groups.keys())[0]
one_turtle_df = turtles_df.get_group(one_turtle)
one_turtle_df
# Out:
#      who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 791  289     0      45.298566      27.007091                  1
# 792  289     1      44.998651      26.999968                  1
# 793  289     2      44.876843      26.725809                  1
# 794  289     3      44.755036      26.451651                  1
# 795  289     4      44.633228      26.177492                  1
# ..   ...   ...            ...            ...                ...
# 898  289   107      23.437620       8.452292                  0
# 899  289   108      23.545952       8.172535                  0
# 900  289   109      23.654284       7.892777                  0
# 901  289   110      23.762616       7.613020                  0
# 902  289   111      23.870949       7.333263                  0
#
#      platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 791                  1                13                26             none
# 792                  1                13                26             none
# 793                  1                13                26             none
# 794                  1                13                25             none
# 795                  1                13                25             none
# ..                 ...               ...               ...              ...
# 898                  0                22                 7             none
# 899                  0                23                 7             none
# 900                  0                23                 7             none
# 901                  0                23                 7             none
# 902                  0                23                 6             none
#
#      xcor-final-pos  ...  floor-id-final-pos  platform--final-pos  \
# 791       45.298566  ...                   1                    1
# 792       44.998651  ...                   1                    1
# 793       44.876843  ...                   1                    1
# 794       44.755036  ...                   1                    1
# 795       44.633228  ...                   1                    1
# ..              ...  ...                 ...                  ...
# 898       23.437620  ...                   0                    0
# 899       23.545952  ...                   0                    0
# 900       23.654284  ...                   0                    0
# 901       23.762616  ...                   0                    0
# 902       23.870949  ...                   0                    0
#
#      floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 791                 13                 26  292.000000              0
# 792                 13                 26  268.639529              0
# 793                 13                 26  203.955391              0
# 794                 13                 25  203.955391              0
# 795                 13                 25  203.955391              0
# ..                 ...                ...         ...            ...
# 898                 22                  7  158.831793              0
# 899                 23                  7  158.831793              0
# 900                 23                  7  158.831793              0
# 901                 23                  7  158.831793              0
# 902                 23                  6  158.831793              0
#
#      crowdness-1  crowdness-1.2  crowdness-1.4  distance
# 791            0              0              0       NaN
# 792            0              0              0       NaN
# 793            0              0              0       NaN
# 794            0              0              0       NaN
# 795            0              0              0       NaN
# ..           ...            ...            ...       ...
# 898            0              0              0       NaN
# 899            0              0              0       NaN
# 900            0              0              0       NaN
# 901            0              0              0       NaN
# 902            0              0              0       NaN
#
# [112 rows x 21 columns]

# %%
for turtle, turtle_df in turtles_df:
    # Ensure sort by tick
    turtle_df = turtle_df.sort_values('tick', ascending=True)
    prev_x = None
    prev_y = None
    prev_distance = None
    first = True
    for i, row in turtle_df.iterrows():
        if first:
            distance = 0
            first = False
        else:
            x1 = prev_x
            y1 = prev_y
            d1 = prev_distance
            x2 = row['xcor-init-pos']
            y2 = row['ycor-init-pos']
            delta_d = distance_calc(x1, y1, x2, y2)
            distance = d1 + delta_d
            
            
        prev_x = row['xcor-init-pos']
        prev_y = row['ycor-init-pos']
        prev_distance = distance
        # turtles_df.loc[turtle].loc[i, 'distance'] = distance
        df.loc[i, 'distance'] = distance

# %%
df[df['distance']==df['distance'].max()]
# Out:
#       who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 1625  326   173      53.669601       4.295325                  1
#
#       platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 1625                  1                22                 3             none
#
#       xcor-final-pos  ...  floor-id-final-pos  platform--final-pos  \
# 1625       53.669601  ...                   1                    1
#
#       floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 1625                 22                  3  131.791773              0
#
#       crowdness-1  crowdness-1.2  crowdness-1.4   distance
# 1625            0              0              0  85.000828
#
# [1 rows x 21 columns]

# %%
df[df['crowdness-0.8']== df['crowdness-0.8'].max()]
# Out:
#       who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 284   324     0      43.227484       4.071440                  1
# 574   372     0      50.015845      28.567801                  1
# 851   289    60      18.813614      20.980557                  0
# 1232  312    60      18.857752      20.600000                  0
# 1316  394     0      42.999943       4.415741                  1
# 1527  326    75      14.570453      23.052960                  0
# 1626  350     0      50.041433      28.519909                  1
# 2149  428    75      14.617043      22.600000                  0
#
#       platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 284                   1                11                 3             none
# 574                   1                18                28             none
# 851                   0                18                20             none
# 1232                  0                18                20             none
# 1316                  1                11                 3             none
# 1527                  0                14                22             none
# 1626                  1                18                28             none
# 2149                  0                14                22             none
#
#       xcor-final-pos  ...  floor-id-final-pos  platform--final-pos  \
# 284        43.227484  ...                   1                    1
# 574        50.015845  ...                   1                    1
# 851        18.813614  ...                   0                    0
# 1232       18.857752  ...                   0                    0
# 1316       42.999943  ...                   1                    1
# 1527       14.570453  ...                   0                    0
# 1626       50.041433  ...                   1                    1
# 2149       14.617043  ...                   0                    0
#
#       floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 284                  11                  3   93.000000              1
# 574                  18                 28  265.000000              1
# 851                  18                 20   80.273448              1
# 1232                 18                 20  278.116308              1
# 1316                 11                  3   15.000000              1
# 1527                 14                 22   86.857466              1
# 1626                 18                 28  176.000000              1
# 2149                 14                 22  272.846290              1
#
#       crowdness-1  crowdness-1.2  crowdness-1.4   distance
# 284             1              1              1   0.000000
# 574             1              1              1   0.000000
# 851             1              1              1  51.287969
# 1232            1              1              1  17.985612
# 1316            1              1              1   0.000000
# 1527            1              1              1  22.548729
# 1626            1              1              1   0.000000
# 2149            1              1              1  55.724515
#
# [8 rows x 21 columns]

# %%
df[df['crowdness-1']== df['crowdness-1'].max()]
# Out:
#       who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 431   301     4      50.080579       3.664079                  1
# 432   301     5      50.015761       3.935481                  1
# 433   301     6      49.954522       4.217419                  1
# 434   301     7      49.903812       4.512586                  1
# 435   301     8      49.869840       4.825711                  1
# 436   301     9      49.853002       5.159218                  1
# 628   372    54      10.131847      18.209914                  0
# 645   372    71      15.892783      20.157136                  0
# 1039  339     2      50.590023       3.572831                  1
# 1696  350    70      16.041464      20.430950                  0
# 1701  350    75      16.701908      21.530973                  0
# 1706  350    80      16.571577      22.807528                  0
#
#       platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 431                   1                18                 3             none
# 432                   1                18                 3             none
# 433                   1                18                 3             none
# 434                   1                18                 4             none
# 435                   1                18                 4             none
# 436                   1                18                 4             none
# 628                   0                 9                17             none
# 645                   0                15                19             none
# 1039                  1                19                 3             none
# 1696                  0                15                19             none
# 1701                  0                16                21             none
# 1706                  0                16                22             none
#
#       xcor-final-pos  ...  floor-id-final-pos  platform--final-pos  \
# 431        50.080579  ...                   1                    1
# 432        50.015761  ...                   1                    1
# 433        49.954522  ...                   1                    1
# 434        49.903812  ...                   1                    1
# 435        49.869840  ...                   1                    1
# 436        49.853002  ...                   1                    1
# 628        10.131847  ...                   0                    0
# 645        15.892783  ...                   0                    0
# 1039       50.590023  ...                   1                    1
# 1696       16.041464  ...                   0                    0
# 1701       16.701908  ...                   0                    0
# 1706       16.571577  ...                   0                    0
#
#       floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 431                  18                  3  358.518903              0
# 432                  18                  3  358.935330              0
# 433                  18                  3  359.777827              0
# 434                  18                  4    0.688827              0
# 435                  18                  4    1.579908              0
# 436                  18                  4    2.348061              0
# 628                   9                 17  222.142090              0
# 645                  15                 19   52.178268              0
# 1039                 19                  3  328.430349              0
# 1696                 15                 19   50.361840              0
# 1701                 16                 21   10.842968              0
# 1706                 16                 22  271.606077              0
#
#       crowdness-1  crowdness-1.2  crowdness-1.4   distance
# 431             2              2              2   1.090376
# 432             2              2              2   1.369411
# 433             2              2              2   1.657922
# 434             2              2              2   1.957414
# 435             2              2              2   2.272376
# 436             2              2              2   2.606308
# 628             2              2              2  47.167357
# 645             2              2              2  54.584544
# 1039            2              2              2   0.387441
# 1696            2              2              2  54.353825
# 1701            2              2              2  55.762569
# 1706            2              2              2  57.402883
#
# [12 rows x 21 columns]

# %%
df[df['crowdness-1.2']== df['crowdness-1.2'].max()]
# Out:
#       who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 1243  312    71      16.466827      20.009186                  0
#
#       platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 1243                  0                15                19             none
#
#       xcor-final-pos  ...  floor-id-final-pos  platform--final-pos  \
# 1243       16.466827  ...                   0                    0
#
#       floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 1243                 15                 19  203.720891              0
#
#       crowdness-1  crowdness-1.2  crowdness-1.4   distance
# 1243            1              3              3  21.369777
#
# [1 rows x 21 columns]

# %%
df[df['crowdness-1.4']== df['crowdness-1.4'].max()]
# Out:
#       who  tick  xcor-init-pos  ycor-init-pos  floor-id-init-pos  \
# 1243  312    71      16.466827      20.009186                  0
# 1695  350    69      16.013099      20.182457                  0
#
#       platform-init-pos  floor-x-init-pos  floor-y-init-pos floor-transition  \
# 1243                  0                15                19             none
# 1695                  0                15                19             none
#
#       xcor-final-pos  ...  floor-id-final-pos  platform--final-pos  \
# 1243       16.466827  ...                   0                    0
# 1695       16.013099  ...                   0                    0
#
#       floor-x-final-pos  floor-y-final-pos     heading  crowdness-0.8  \
# 1243                 15                 19  203.720891              0
# 1695                 15                 19   50.361840              0
#
#       crowdness-1  crowdness-1.2  crowdness-1.4   distance
# 1243            1              3              3  21.369777
# 1695            0              2              3  54.103718
#
# [2 rows x 21 columns]
